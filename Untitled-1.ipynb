# %%
# Out:
# Running cells with '.venv (Python 3.12.8)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/neerajsharma/src/personal/nikki/tsa/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Read the shapefile
gdf = gpd.read_file('./files/IFF_ECEanalysis2024_DetroitZipCodes_20241219.shp')

# Create a figure with a specific size
fig, ax = plt.subplots(figsize=(15, 10))

# Plot the shapefile with some styling
gdf.plot(
    ax=ax,
    edgecolor='black',     # Border color of polygons
    linewidth=0.5,         # Width of borders
    alpha=0.7,             # Transparency of polygons
)

# Add a title
plt.title('Predominant Race Distribution', fontsize=16)

# Add axis labels
plt.xlabel('Longitude', fontsize=12)
plt.ylabel('Latitude', fontsize=12)

# Let's see what columns we have in the data
print("Available columns in the dataset:", gdf.columns.tolist())

# Show the plot
plt.show()

# Display first few rows of the data to understand its structure
print("\nFirst few rows of the data:")
print(gdf.head())
# Out:
# Available columns in the dataset: ['FID', 'GEOID10', 'Shape_Leng', 'NumProv', 'Gap_02', 'Gap_35', 'Gap_05', 'Sub_02', 'Sub_35', 'Sub_05', 'EHS_02', 'HS_35', 'EHSHS_05', 'GSRP_PreK', 'NumQProv', 'QGap_02', 'QGap_35', 'QGap_05', 'QSub_02', 'QSub_35', 'QSub_05', 'QEHS_02', 'QHS_35', 'QEHSHS_05', 'QGSRP_PreK', 'Dmd_02', 'Dmd_35', 'Dmd_05', 'DmdSub02', 'DmdSub35', 'DmdSub05', 'DmdEHS02', 'DmdHS35', 'DmdEHSHS', 'DmdGSRP', 'ObjectID_1', 'Shape__Are', 'Shape__Len', 'geometry']
# First few rows of the data:
#    FID GEOID10  Shape_Leng  NumProv  Gap_02  Gap_35  Gap_05  Sub_02  Sub_35  \
# 0    1   48209    0.222467       11   -1500   -1004   -2505   -1281   -1223
# 1    2   48210    0.180856       12   -1451   -1034   -2485   -1399   -1396
# 2    3   48211    0.232376        2    -170    -117    -287    -151    -158
# 3    4   48212    0.188663        4    -700    -638   -1338    -577    -553
# 4    5   48201    0.151484        7    -152      43    -109    -195    -186
#
#    Sub_05  ...  DmdSub35  DmdSub05  DmdEHS02  DmdHS35  DmdEHSHS  DmdGSRP  \
# 0   -2503  ...      1232      2512       864      834      1698      440
# 1   -2795  ...      1398      2797       826      825      1651      482
# 2    -310  ...       158       310        85       91       176       62
# 3   -1130  ...       560      1138       334      323       657      196
# 4    -381  ...       197       399       166      161       327       81
#
#    ObjectID_1    Shape__Are    Shape__Len  \
# 0           3  1.922250e+08  68385.611068
# 1          14  1.404847e+08  54750.014020
# 2          10  1.166317e+08  73572.715902
# 3          24  1.494511e+08  59445.912068
# 4          17  5.590077e+07  46752.696250
#
#                                             geometry
# 0  POLYGON ((13453188.624 301086.243, 13453336.95...
# 1  POLYGON ((13450409.143 307362.522, 13450712.90...
# 2  POLYGON ((13470962.08 329360.18, 13471360.796 ...
# 3  POLYGON ((13470041.145 339863.728, 13470320.27...
# 4  POLYGON ((13471784.662 313323.377, 13472078.94...
#
# [5 rows x 39 columns]
